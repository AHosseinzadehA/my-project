# %% [markdown]
# #### • Table of the content
#
# 1. [PIP Commands](#1)
# 2. [PIP Cheat Sheet](#1-1)
# 3. [More Info (Follow Me on LinkedIn)](#end)
#
# ---

# %% [markdown]
# <a name="1"></a>
# ## PIP Commands
#
# 🔸 There are some useful commands that you can use with **PIP**.
#
# ```
# pip install library-name
# ```
# ```
# pip uninstall library-name
# ```
# ```
# pip list
# ```
# ```
# pip show library-name
# ```
# ```
# pip freeze
# ```
# ```
# pip freeze > requirements.txt
# ```
# ```
# pip install -r requirements.txt
# ```
# ---
#
# <a name="1-1"></a>
# 👀 **PIP Cheat Sheet**
#
# ![PIP cheat sheet](../../PDFs/Images/PIP-Cheat-Sheet-01.jpg)
#
# ---
#
# 💡 **NOTE**
#
# 🔸 You can use the **above commands** directly in Jupyter notebook **code cell**, by the used of **!** before the command

# %%
pip show openpyxl
# Out:
# Name: openpyxl
# Version: 3.1.5
# Summary: A Python library to read/write Excel 2010 xlsx/xlsm files
# Home-page: https://openpyxl.readthedocs.io
# Author: See AUTHORS
# Author-email: charlie.clark@clark-consulting.eu
# License: MIT
# Location: c:\users\arezoo\desktop\my_jupyters\myenv\lib\site-packages
# Requires: et-xmlfile
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip freeze
# Out:
# anyio==4.9.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asttokens==3.0.0
# async-lru==2.0.5
# attrs==25.3.0
# babel==2.17.0
# beautifulsoup4==4.13.3
# bleach==6.2.0
# certifi==2025.1.31
# cffi==1.17.1
# charset-normalizer==3.4.1
# colorama==0.4.6
# comm==0.2.2
# contourpy==1.3.0
# cycler==0.12.1
# debugpy==1.8.14
# decorator==5.2.1
# defusedxml==0.7.1
# entrypoints==0.4
# et-xmlfile==2.0.0
# exceptiongroup==1.2.2
# executing==2.2.0
# fastjsonschema==2.21.1
# fonttools==4.58.0
# fqdn==1.5.1
# h11==0.14.0
# httpcore==1.0.8
# httpx==0.28.1
# idna==3.10
# importlib-metadata==8.6.1
# importlib-resources==6.5.2
# ipykernel==6.29.5
# ipython==8.18.1
# ipython-genutils==0.2.0
# ipywidgets==8.1.6
# isoduration==20.11.0
# jedi==0.19.2
# jinja2==3.1.6
# json5==0.12.0
# jsonpointer==3.0.0
# jsonschema==4.23.0
# jsonschema-specifications==2024.10.1
# jupyter==1.1.1
# jupyter-client==7.4.9
# jupyter-console==6.6.3
# jupyter-core==5.7.2
# jupyter-events==0.12.0
# ...

# %% [markdown]
# ---
# <a name="end"></a>
# ### Congrats!
#
# 🔥 Let's go to the next session.
#
# 📝 This Jupyter notebook has been created by [Ahmad Ahmadi](https://www.linkedin.com/in/ahmad-ahmadi95/). Please follow me and [izlearn](https://www.linkedin.com/company/izlearn) on LinkedIn social media.
#
# 🌐 Visit your website for more courses [izlearn.ir](https://izlearn.ir)
